# %% [markdown]
# # NAF / ROME Link Factory
# * Utiliser les diverses données pour calculer une table de correspondance rome / naf
#
# ## Lancement
# Les cellules peuvent être lancées automatiquement ( _run all cells_ ), l'exécution s'arrêtera automatiquement après avoir crée le fichier output: ../outputs/andi_rome2naf_|date|.csv
#
#
# ## Autres idées non exploitées:
# - pousser certains domaines naf manuellement reliés aux romes
# - exploiter les codes OGR (données insuffisantes)
# - obtenir des données plus larges, sur une pluse grande durée (cf DPAE)
# - intégrer nombre d'entreprises et leur taille moyenne (sur tout le territoire) (cf. sirene/insee)
# - plus dynamique: intégrer variance, écart type, ...
# - ...

# %% [markdown]
# ### Obtention des labels et autres données

# %%
## Chargement des labels naf, rome, ogr
from IPython.display import display, HTML
import pandas as pd
import numpy as np

# NAF
naf_labels = pd.read_csv('../ressources/list_NAF_LBB.csv', sep='|', encoding="utf-8")
naf_labels.columns = ['nafdot', 'naf', 'label']
print(f"Obtained {len(naf_labels)} NAF labels")
# display(HTML(naf_labels.head(5).to_html()))

# ROME
rome_labels = pd.read_csv('../ressources/liste_rome_LBB.csv', sep=',', encoding="utf-8")
rome_labels.columns = ['rome', 'rome_1', 'rome_2', 'rome_3', 'label', 'slug']
print(f"Obtained {len(rome_labels)} ROME labels")
# display(HTML(rome_labels.head(5).to_html()))

# Chargement des statistiques d'emploi
emploi_rome_naf = pd.read_csv('../ressources/contrats_30j.csv', sep=',', encoding="utf-8")[['ROME', 'APE700', 'nb_embauches']]
emploi_rome_naf.columns = ['rome', 'naf', 'embauches']
# display(HTML(emploi_rome_naf.head(5).to_html()))
        
    
# Calcul des ratios
naf_embauches = emploi_rome_naf[['naf', 'embauches']].groupby('naf').agg(
    embauches_total_n=pd.NamedAgg(column='embauches', aggfunc=sum)
)
rome_embauches = emploi_rome_naf[['rome', 'embauches']].groupby('rome').agg(
    embauches_total_r=pd.NamedAgg(column='embauches', aggfunc=sum)
)


naf_i = (
emploi_rome_naf
    .merge(naf_embauches, on='naf')
    .merge(rome_embauches, on='rome')
)
naf_i['ratio_naf'] = ( naf_i.embauches / naf_i.embauches_total_n ) * 100
naf_i['ratio_rome'] = ( naf_i.embauches / naf_i.embauches_total_r ) * 100

naf_i = naf_i.sort_values(by=['ratio_naf'], ascending=False)
naf_i.columns
# Out:
# Obtained 732 NAF labels
# Obtained 531 ROME labels
# Index(['rome', 'naf', 'embauches', 'embauches_total_n', 'embauches_total_r',
#        'ratio_naf', 'ratio_rome'],
#       dtype='object')

# %% [markdown]
# ### Fonction de calcul du tableau de correspondance ROME vers NAF

# %%
# Rome=>Naf in function form
def rome2nafz(rome, df_in, output_size=15):
    """
    Generate naf list using input rome code and specific dataframe:
    ['rome', 'naf', 'embauches', 'embauches_total_n', 'embauches_total_r', 'ratio_naf', 'ratio_rome']
    
    - First a table is generated listing the naf codes who employ the highest percentage
    (from their total recruitments) of the specified rome code, a score is specified with
    a binning technique
    - Then the NAF codes who also appear in the list of where the specified rome code tends
    to work at are boosted
    - Finaly the result is filtered keeping only those with a score of 1 or higher, and from those
    only the first 15 are kept (can be changed by parameter)
    """
    df_nf = (
    df_in.loc[df_in.rome == rome]
         .sort_values(by=['ratio_naf'], ascending=False)
    )
    df_nf['cumsum'] =  100 - df_nf['ratio_rome'].cumsum()
    df_nf = df_nf.loc[df_nf['cumsum'] > 25]
    df_nf['score'] = pd.to_numeric(pd.cut(
        df_nf['ratio_naf'],
        bins=[1, 2, 5, 10, 50, 100],
        labels=[0, 1, 2, 3, 4]
    ))
    
    df_rs = (
    df_in.loc[naf_i.rome == rome ]
         .sort_values(by=['ratio_rome'], ascending=False)
    )
    df_rs['cumsum'] =  100 - df_rs['ratio_rome'].cumsum()
    df_rs = df_rs.head(10)
    
    df_nf.loc[df_nf['naf'].isin(df_rs['naf']), 'score'] += 1
    df_nf = df_nf.loc[df_nf['score'].ge(1)]
    
    return (
        df_nf.sort_values(by=['score'], ascending=False)
             .head(output_size)
    )[['rome', 'naf', 'score']]

# %% [markdown]
# ### Vérification de la fonction

# %%
# Function Test
ROME = 'D1101'
print(f"Table ROME=>NAF pour \"{rome_labels.loc[(rome_labels['rome'] == ROME, 'label')].iloc[0]}\"")
df  = rome2nafz(ROME, naf_i)
df.merge(naf_labels, on='naf')[['naf', 'label','score']]
assert(len(df) == 15)
df.head(5)
# Out:
# Table ROME=>NAF pour "Boucherie"
#         rome    naf  score
# 12720  D1101  4722Z    4.0
# 12883  D1101  1013B    3.0
# 12562  D1101  1011Z    3.0
# 12696  D1101  4632A    3.0
# 12716  D1101  4711D    2.0

# %% [markdown]
# ### Calcul de pour l'ensemble des codes ROME

# %%
result_table = {}
for index, row in rome_labels.iterrows():
    result_table[row.rome] = rome2nafz(str(row.rome), naf_i).to_dict('r')
    print(f"row {index} : {len(result_table[row.rome])} Naf codes for Rome {row.rome} \"{rome_labels.loc[(rome_labels['rome'] == row.rome, 'label')].iloc[0]}\" ")
# Out:
# row 0 : 15 Naf codes for Rome A1101 "Conduite d'engins agricoles et forestiers"
# row 1 : 8 Naf codes for Rome A1201 "Bûcheronnage et élagage"
# row 2 : 2 Naf codes for Rome A1202 "Entretien des espaces naturels"
# row 3 : 15 Naf codes for Rome A1203 "Entretien des espaces verts"
# row 4 : 2 Naf codes for Rome A1204 "Protection du patrimoine naturel"
# row 5 : 3 Naf codes for Rome A1205 "Sylviculture"
# row 6 : 8 Naf codes for Rome A1301 "Conseil et assistance technique en agriculture"
# row 7 : 4 Naf codes for Rome A1302 "Contrôle et diagnostic technique en agriculture"
# row 8 : 13 Naf codes for Rome A1303 "Ingénierie en agriculture et environnement naturel"
# row 9 : 15 Naf codes for Rome A1401 "Aide agricole de production fruitière ou viticole"
# row 10 : 13 Naf codes for Rome A1402 "Aide agricole de production légumière ou végétale"
# row 11 : 8 Naf codes for Rome A1403 "Aide d'élevage agricole et aquacole"
# row 12 : 6 Naf codes for Rome A1404 "Aquaculture"
# row 13 : 11 Naf codes for Rome A1405 "Arboriculture et viticulture"
# row 14 : 0 Naf codes for Rome A1406 "Encadrement équipage de la pêche"
# row 15 : 15 Naf codes for Rome A1407 "Élevage bovin ou équin"
# row 16 : 4 Naf codes for Rome A1408 "Élevage d'animaux sauvages ou de compagnie"
# row 17 : 2 Naf codes for Rome A1409 "Élevage de lapins et volailles"
# row 18 : 3 Naf codes for Rome A1410 "Élevage ovin ou caprin"
# row 19 : 3 Naf codes for Rome A1411 "Élevage porcin"
# row 20 : 3 Naf codes for Rome A1412 "Fabrication et affinage de fromages"
# row 21 : 10 Naf codes for Rome A1413 "Fermentation de boissons alcoolisées"
# row 22 : 15 Naf codes for Rome A1414 "Horticulture et maraîchage"
# row 23 : 2 Naf codes for Rome A1415 "Equipage de la pêche"
# row 24 : 15 Naf codes for Rome A1416 "Polyculture, élevage"
# row 25 : 0 Naf codes for Rome A1417 "Saliculture"
# row 26 : 4 Naf codes for Rome A1501 "Aide aux soins animaux"
# row 27 : 1 Naf codes for Rome A1502 "Podologie animale"
# row 28 : 0 Naf codes for Rome A1503 "Toilettage des animaux"
# row 29 : 1 Naf codes for Rome A1504 "Santé animale"
# row 30 : 3 Naf codes for Rome B1101 "Création en arts plastiques"
# row 31 : 1 Naf codes for Rome B1201 "Réalisation d'objets décoratifs et utilitaires en céramique et matériaux de synthèse"
# row 32 : 0 Naf codes for Rome B1301 "Décoration d'espaces de vente et d'exposition"
# row 33 : 2 Naf codes for Rome B1302 "Décoration d'objets d'art et artisanaux"
# row 34 : 1 Naf codes for Rome B1303 "Gravure - ciselure"
# row 35 : 0 Naf codes for Rome B1401 "Réalisation d'objets en lianes, fibres et brins végétaux"
# row 36 : 2 Naf codes for Rome B1402 "Reliure et restauration de livres et archives"
# row 37 : 1 Naf codes for Rome B1501 "Fabrication et réparation d'instruments de musique"
# row 38 : 1 Naf codes for Rome B1601 "Métallerie d'art"
# row 39 : 1 Naf codes for Rome B1602 "Réalisation d'objets artistiques et fonctionnels en verre"
# row 40 : 6 Naf codes for Rome B1603 "Réalisation d'ouvrages en bijouterie, joaillerie et orfèvrerie"
# row 41 : 4 Naf codes for Rome B1604 "Réparation - montage en systèmes horlogers"
# row 42 : 0 Naf codes for Rome B1701 "Conservation et reconstitution d'espèces animales"
# row 43 : 0 Naf codes for Rome B1801 "Réalisation d'articles de chapellerie"
# row 44 : 3 Naf codes for Rome B1802 "Réalisation d'articles en cuir et matériaux souples (hors vêtement)"
# row 45 : 14 Naf codes for Rome B1803 "Réalisation de vêtements sur mesure ou en petite série"
# row 46 : 1 Naf codes for Rome B1804 "Réalisation d'ouvrages d'art en fils"
# row 47 : 11 Naf codes for Rome B1805 "Stylisme"
# row 48 : 5 Naf codes for Rome B1806 "Tapisserie - décoration en ameublement"
# row 49 : 0 Naf codes for Rome C1101 "Conception - développement produits d'assurances"
# row 50 : 12 Naf codes for Rome C1102 "Conseil clientèle en assurances"
# row 51 : 0 Naf codes for Rome C1103 "Courtage en assurances"
# row 52 : 0 Naf codes for Rome C1104 "Direction d'exploitation en assurances"
# row 53 : 2 Naf codes for Rome C1105 "Études actuarielles en assurances"
# row 54 : 1 Naf codes for Rome C1106 "Expertise risques en assurances"
# row 55 : 1 Naf codes for Rome C1107 "Indemnisations en assurances"
# row 56 : 0 Naf codes for Rome C1108 "Management de groupe et de service en assurances"
# row 57 : 11 Naf codes for Rome C1109 "Rédaction et gestion en assurances"
# row 58 : 0 Naf codes for Rome C1110 "Souscription d'assurances"
# row 59 : 10 Naf codes for Rome C1201 "Accueil et services bancaires"
# row 60 : 6 Naf codes for Rome C1202 "Analyse de crédits et risques bancaires"
# row 61 : 2 Naf codes for Rome C1203 "Relation clients banque/finance"
# row 62 : 0 Naf codes for Rome C1204 "Conception et expertise produits bancaires et financiers"
# row 63 : 3 Naf codes for Rome C1205 "Conseil en gestion de patrimoine financier"
# row 64 : 12 Naf codes for Rome C1206 "Gestion de clientèle bancaire"
# row 65 : 0 Naf codes for Rome C1207 "Management en exploitation bancaire"
# row 66 : 4 Naf codes for Rome C1301 "Front office marchés financiers"
# row 67 : 6 Naf codes for Rome C1302 "Gestion back et middle-office marchés financiers"
# row 68 : 3 Naf codes for Rome C1303 "Gestion de portefeuilles sur les marchés financiers"
# row 69 : 9 Naf codes for Rome C1401 "Gestion en banque et assurance"
# row 70 : 4 Naf codes for Rome C1501 "Gérance immobilière"
# row 71 : 6 Naf codes for Rome C1502 "Gestion locative immobilière"
# row 72 : 7 Naf codes for Rome C1503 "Management de projet immobilier"
# row 73 : 14 Naf codes for Rome C1504 "Transaction immobilière"
# row 74 : 15 Naf codes for Rome D1101 "Boucherie"
# row 75 : 11 Naf codes for Rome D1102 "Boulangerie - viennoiserie"
# row 76 : 2 Naf codes for Rome D1103 "Charcuterie - traiteur"
# row 77 : 13 Naf codes for Rome D1104 "Pâtisserie, confiserie, chocolaterie et glacerie"
# row 78 : 4 Naf codes for Rome D1105 "Poissonnerie"
# row 79 : 15 Naf codes for Rome D1106 "Vente en alimentation"
# row 80 : 1 Naf codes for Rome D1107 "Vente en gros de produits frais"
# row 81 : 2 Naf codes for Rome D1201 "Achat vente d'objets d'art, anciens ou d'occasion"
# row 82 : 6 Naf codes for Rome D1202 "Coiffure"
# row 83 : 2 Naf codes for Rome D1203 "Hydrothérapie"
# row 84 : 2 Naf codes for Rome D1204 "Location de véhicules ou de matériel de loisirs"
# row 85 : 1 Naf codes for Rome D1205 "Nettoyage d'articles textiles ou cuirs"
# row 86 : 3 Naf codes for Rome D1206 "Réparation d'articles en cuir et matériaux souples"
# row 87 : 2 Naf codes for Rome D1207 "Retouches en habillement"
# row 88 : 15 Naf codes for Rome D1208 "Soins esthétiques et corporels"
# row 89 : 6 Naf codes for Rome D1209 "Vente de végétaux"
# row 90 : 2 Naf codes for Rome D1210 "Vente en animalerie"
# row 91 : 15 Naf codes for Rome D1211 "Vente en articles de sport et loisirs"
# row 92 : 15 Naf codes for Rome D1212 "Vente en décoration et équipement du foyer"
# row 93 : 5 Naf codes for Rome D1213 "Vente en gros de matériel et équipement"
# row 94 : 15 Naf codes for Rome D1214 "Vente en habillement et accessoires de la personne"
# row 453 : 3 Naf codes for Rome M1202 "Audit et contrôle comptables et financiers"
# row 454 : 15 Naf codes for Rome M1203 "Comptabilité"
# row 455 : 12 Naf codes for Rome M1204 "Contrôle de gestion"
# row 456 : 11 Naf codes for Rome M1205 "Direction administrative et financière"
# row 457 : 1 Naf codes for Rome M1206 "Management de groupe ou de service comptable"
# row 458 : 0 Naf codes for Rome M1207 "Trésorerie et financement"
# row 459 : 1 Naf codes for Rome M1301 "Direction de grande entreprise ou d'établissement public"
# row 460 : 4 Naf codes for Rome M1302 "Direction de petite ou moyenne entreprise"
# row 461 : 2 Naf codes for Rome M1401 "Conduite d'enquêtes"
# row 462 : 11 Naf codes for Rome M1402 "Conseil en organisation et management d'entreprise"
# row 463 : 1 Naf codes for Rome M1403 "Études et prospectives socio-économiques"
# row 464 : 0 Naf codes for Rome M1404 "Management et gestion d'enquêtes"
# row 465 : 15 Naf codes for Rome M1501 "Assistanat en ressources humaines"
# row 466 : 13 Naf codes for Rome M1502 "Développement des ressources humaines"
# row 467 : 8 Naf codes for Rome M1503 "Management des ressources humaines"
# row 468 : 15 Naf codes for Rome M1601 "Accueil et renseignements"
# row 469 : 15 Naf codes for Rome M1602 "Opérations administratives"
# row 470 : 3 Naf codes for Rome M1603 "Distribution de documents"
# row 471 : 15 Naf codes for Rome M1604 "Assistanat de direction"
# row 472 : 15 Naf codes for Rome M1605 "Assistanat technique et administratif"
# row 473 : 1 Naf codes for Rome M1606 "Saisie de données"
# row 474 : 15 Naf codes for Rome M1607 "Secrétariat"
# row 475 : 5 Naf codes for Rome M1608 "Secrétariat comptable"
# row 476 : 15 Naf codes for Rome M1609 "Secrétariat et assistanat médical ou médico-social"
# row 477 : 4 Naf codes for Rome M1701 "Administration des ventes"
# row 478 : 0 Naf codes for Rome M1702 "Analyse de tendance"
# row 479 : 12 Naf codes for Rome M1703 "Management et gestion de produit"
# row 480 : 2 Naf codes for Rome M1704 "Management relation clientèle"
# row 481 : 15 Naf codes for Rome M1705 "Marketing"
# row 482 : 1 Naf codes for Rome M1706 "Promotion des ventes"
# row 483 : 15 Naf codes for Rome M1707 "Stratégie commerciale"
# row 484 : 14 Naf codes for Rome M1801 "Administration de systèmes d'information"
# row 485 : 4 Naf codes for Rome M1802 "Expertise et support en systèmes d'information"
# row 486 : 12 Naf codes for Rome M1803 "Direction des systèmes d'information"
# row 487 : 5 Naf codes for Rome M1804 "Études et développement de réseaux de télécoms"
# row 488 : 15 Naf codes for Rome M1805 "Études et développement informatique"
# row 489 : 4 Naf codes for Rome M1806 "Conseil et maîtrise d'ouvrage en systèmes d'information"
# row 490 : 0 Naf codes for Rome M1807 "Exploitation de systèmes de communication et de commandement"
# row 491 : 2 Naf codes for Rome M1808 "Information géographique"
# row 492 : 0 Naf codes for Rome M1809 "Information météorologique"
# row 493 : 5 Naf codes for Rome M1810 "Production et exploitation de systèmes d'information"
# row 494 : 15 Naf codes for Rome N1101 "Conduite d'engins de déplacement des charges"
# row 495 : 1 Naf codes for Rome N1102 "Déménagement"
# row 496 : 15 Naf codes for Rome N1103 "Magasinage et préparation de commandes"
# row 497 : 4 Naf codes for Rome N1104 "Manoeuvre et conduite d'engins lourds de manutention"
# row 498 : 15 Naf codes for Rome N1105 "Manutention manuelle de charges"
# row 499 : 1 Naf codes for Rome N1201 "Affrètement transport"
# row 500 : 2 Naf codes for Rome N1202 "Gestion des opérations de circulation internationale des marchandises"
# row 501 : 3 Naf codes for Rome N1301 "Conception et organisation de la chaîne logistique"
# row 502 : 0 Naf codes for Rome N1302 "Direction de site logistique"
# row 503 : 15 Naf codes for Rome N1303 "Intervention technique d'exploitation logistique"
# row 504 : 5 Naf codes for Rome N2101 "Navigation commerciale aérienne"
# row 505 : 3 Naf codes for Rome N2102 "Pilotage et navigation technique aérienne"
# row 506 : 4 Naf codes for Rome N2201 "Personnel d'escale aéroportuaire"
# row 507 : 0 Naf codes for Rome N2202 "Contrôle de la navigation aérienne"
# row 508 : 2 Naf codes for Rome N2203 "Exploitation des pistes aéroportuaires"
# row 509 : 3 Naf codes for Rome N2204 "Préparation des vols"
# row 510 : 0 Naf codes for Rome N2205 "Direction d'escale et exploitation aéroportuaire"
# row 511 : 6 Naf codes for Rome N3101 "Encadrement de la navigation maritime"
# row 512 : 3 Naf codes for Rome N3102 "Equipage de la navigation maritime"
# row 513 : 4 Naf codes for Rome N3103 "Navigation fluviale"
# row 514 : 2 Naf codes for Rome N3201 "Exploitation des opérations portuaires et du transport maritime"
# row 515 : 0 Naf codes for Rome N3202 "Exploitation du transport fluvial"
# row 516 : 1 Naf codes for Rome N3203 "Manutention portuaire"
# row 517 : 15 Naf codes for Rome N4101 "Conduite de transport de marchandises sur longue distance"
# row 518 : 10 Naf codes for Rome N4102 "Conduite de transport de particuliers"
# row 519 : 7 Naf codes for Rome N4103 "Conduite de transport en commun sur route"
# row 520 : 0 Naf codes for Rome N4104 "Courses et livraisons express"
# row 521 : 15 Naf codes for Rome N4105 "Conduite et livraison par tournées sur courte distance"
# row 522 : 0 Naf codes for Rome N4201 "Direction d'exploitation des transports routiers de marchandises"
# row 523 : 0 Naf codes for Rome N4202 "Direction d'exploitation des transports routiers de personnes"
# row 524 : 4 Naf codes for Rome N4203 "Intervention technique d'exploitation des transports routiers de marchandises"
# row 525 : 0 Naf codes for Rome N4204 "Intervention technique d'exploitation des transports routiers de personnes"
# row 526 : 2 Naf codes for Rome N4301 "Conduite sur rails"
# row 527 : 1 Naf codes for Rome N4302 "Contrôle des transports en commun"
# row 528 : 1 Naf codes for Rome N4401 "Circulation du réseau ferré"
# row 529 : 1 Naf codes for Rome N4402 "Exploitation et manoeuvre des remontées mécaniques"
# row 530 : 1 Naf codes for Rome N4403 "Manoeuvre du réseau ferré"

# %% [markdown]
# ### Écriture du fichier CSV et fin du traitement

# %%
# Write CSV File
import csv
import time
output = f"../outputs/andi_rome2naf_{time.strftime('%Y%m%d')}.csv"
i = 0
with open(output, 'w') as file:
    writer = csv.DictWriter(
        file,
        delimiter=',',
        quotechar='"',
        quoting=csv.QUOTE_MINIMAL,
        fieldnames=['rome', 'rome_label', 'naf', 'naf_label', 'score']
    )
    writer.writeheader()
    for rome, naflist in result_table.items():
        for data in naflist:
            data['rome_label'] = rome_labels.loc[(rome_labels['rome'] == rome, 'label')].iloc[0]
            data['naf_label'] = naf_labels.loc[(naf_labels['naf'] == data['naf'], 'label')].iloc[0]
            writer.writerow(data)
            i += 1
print(f'Wrote {i} rows to {output}')

# Crash to end automatic cell execution
raise SystemExit("Fin traitement automatique")
# Out:
# Wrote 3026 rows to ../outputs/andi_rome2naf_20191203.csv
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: Fin traitement automatique
# /home/pieterjan/.local/share/virtualenvs/andi-data-CDydVwxE/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3334: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %% [markdown]
# ### Code historique - documentation

# %%
# Legacy Code

# df_ok['score'] = 0
# df_ok.loc[df_cumsum < 15, 'score'] = 5
# df_ok['score'] = pd.cut(
 #   df_ok['cumsum'],
 #   bins=[0, 15, 30, 45, 60, 100],
 #   labels=[5, 4, 3, 2, 1]
#)
#df_ok

#df_base['score'] = 0
#df_base.loc[df_base['cumsum'].ge(0), 'score'] = 0
#df_base.loc[df_base['cumsum'].ge(15).lt(30), 'score'] = 1
#df_base.loc[df_base['cumsum'].ge(30).lt(45), 'score'] = 2
#df_base.loc[df_base['cumsum'].ge(45).lt(60), 'score'] = 3
#df_base.loc[df_base['cumsum'].ge(60), 'score'] = 4
#df_base

# %%
def display_result(rome, table, naf_labels):
    print(f"Résultat(s) pour {rome} - \"{rome_labels.loc[(rome_labels['rome'] == rome, 'label')].iloc[0]}\"")
    df = pd.DataFrame(table[rome])
    df = df.merge(naf_labels, on='naf')[['naf', 'label','score']]
    display(HTML(df.head(15).to_html()))


display_result('A1303', result_table, naf_labels)
display_result('M1607', result_table, naf_labels)
# rome2nafz(t1, naf_i)

# %%
# Compute best nafs for rome
ROME = 'M1705'

print(f"Table ROME=>NAF pour \"{rome_labels.loc[(rome_labels['rome'] == ROME, 'label')].iloc[0]}\"")

# Basic order based on employment percentage
# Use rome recruitment % by naf ratio, stop @ 75% of total rome pool
df_base = (
naf_i.loc[naf_i.rome == ROME]
    .sort_values(by=['ratio_naf'], ascending=False)
)
df_base['cumsum'] =  100 - df_base['ratio_rome'].cumsum()
df_base = df_base.loc[df_base['cumsum'] > 25]
df_base['score'] = pd.to_numeric(pd.cut(
    df_base['ratio_naf'],
    bins=[1, 2, 5, 10, 50, 100],
    labels=[0, 1, 2, 3, 4]
))

# Boosting scores with rome orientations
# If naf is in top 10 of rome destinations, increment score
df_rs = (
naf_i.loc[naf_i.rome == ROME ]
    .sort_values(by=['ratio_rome'], ascending=False)
)
df_rs['cumsum'] =  100 - df_rs['ratio_rome'].cumsum()
df_rs = df_rs.head(10)
df_base.loc[df_base['naf'].isin(df_rs['naf']), 'score'] += 1
df_base = df_base.loc[df_base['score'].ge(1)]

# Display
(
df_base
    .merge(naf_labels, on='naf')
    .sort_values(by=['score'], ascending=False)
    [['rome', 'naf', 'label','score']]
).head(15)
