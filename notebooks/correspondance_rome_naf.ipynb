# %% [markdown]
# # NAF / ROME Link Factory
# * Utiliser les diverses données pour calculer une table de correspondance rome / naf
#
# ## Lancement
# Les cellules peuvent être lancées automatiquement ( _run all cells_ ), l'exécution s'arrêtera automatiquement après avoir crée le fichier output: ../outputs/andi_rome2naf_|date|.csv
#
#
# ## Autres idées non exploitées:
# - pousser certains domaines naf manuellement reliés aux romes
# - exploiter les codes OGR (données insuffisantes)
# - obtenir des données plus larges, sur une pluse grande durée (cf DPAE)
# - intégrer nombre d'entreprises et leur taille moyenne (sur tout le territoire) (cf. sirene/insee)
# - plus dynamique: intégrer variance, écart type, ...
# - ...
#
# ## A vérifier:
# - Anomalie des fromagers: NAF-1051C et ROME-A1412, peu de recrutement mais ils y vont en masse

# %% [markdown]
# ### Obtention des labels et autres données

# %%
## Chargement des labels naf, rome, ogr
from IPython.display import display, HTML
import pandas as pd
import numpy as np

# NAF
naf_labels = pd.read_csv('/ressources/list_NAF_LBB.csv', sep='|', encoding="utf-8")
naf_labels.columns = ['nafdot', 'naf', 'label']
print(f"Obtained {len(naf_labels)} NAF labels")
# display(HTML(naf_labels.head(5).to_html()))

# ROME
rome_labels = pd.read_csv('/ressources/liste_rome_LBB.csv', sep=',', encoding="utf-8")
rome_labels.columns = ['rome', 'rome_1', 'rome_2', 'rome_3', 'label', 'slug']
print(f"Obtained {len(rome_labels)} ROME labels")
# display(HTML(rome_labels.head(5).to_html()))

# Chargement des statistiques d'emploi
emploi_rome_naf = pd.read_csv('/ressources/contrats_30j.csv', sep=',', encoding="utf-8")[['ROME', 'APE700', 'nb_embauches']]
emploi_rome_naf.columns = ['rome', 'naf', 'embauches']
# display(HTML(emploi_rome_naf.head(5).to_html()))
        
    
# Calcul des ratios
naf_embauches = emploi_rome_naf[['naf', 'embauches']].groupby('naf').agg(
    embauches_total_n=pd.NamedAgg(column='embauches', aggfunc=sum)
)
rome_embauches = emploi_rome_naf[['rome', 'embauches']].groupby('rome').agg(
    embauches_total_r=pd.NamedAgg(column='embauches', aggfunc=sum)
)


naf_i = (
emploi_rome_naf
    .merge(naf_embauches, on='naf')
    .merge(rome_embauches, on='rome')
)
naf_i['ratio_naf'] = ( naf_i.embauches / naf_i.embauches_total_n ) * 100
naf_i['ratio_rome'] = ( naf_i.embauches / naf_i.embauches_total_r ) * 100

naf_i = naf_i.sort_values(by=['ratio_naf'], ascending=False)
naf_i.columns
# Out:
# Obtained 732 NAF labels
# Obtained 531 ROME labels
# Index(['rome', 'naf', 'embauches', 'embauches_total_n', 'embauches_total_r',
#        'ratio_naf', 'ratio_rome'],
#       dtype='object')

# %% [markdown]
# ### Fonction de calcul du tableau de correspondance ROME vers NAF

# %%
# Rome=>Naf in function form
# Deprecated
def rome2nafz_v1(rome, df_in, output_size=15):
    """
    Generate naf list using input rome code and specific dataframe:
    ['rome', 'naf', 'embauches', 'embauches_total_n', 'embauches_total_r', 'ratio_naf', 'ratio_rome']
    
    - First a table is generated listing the naf codes who employ the highest percentage
    (from their total recruitments) of the specified rome code, a score is specified with
    a binning technique
    - Then the NAF codes who also appear in the list of where the specified rome code tends
    to work at are boosted
    - Finaly the result is filtered keeping only those with a score of 1 or higher, and from those
    only the first 15 are kept (can be changed by parameter)
    """
    df_nf = (
    df_in.loc[df_in.rome == rome]
         .sort_values(by=['ratio_naf'], ascending=False)
    )
    df_nf['cumsum'] =  100 - df_nf['ratio_rome'].cumsum()
    df_nf = df_nf.loc[df_nf['cumsum'] > 25]
    df_nf['score'] = pd.to_numeric(pd.cut(
        df_nf['ratio_naf'],
        bins=[1, 2, 5, 10, 50, 100],
        labels=[0, 1, 2, 3, 4]
    ))
    df_nf['score_rome'] = pd.to_numeric(pd.cut(
        df_nf['ratio_rome'],
        bins=[1, 2, 5, 10, 50, 100],
        labels=[0, 1, 2, 3, 4]
    ))
    
    df_rs = (
    df_in.loc[naf_i.rome == rome ]
         .sort_values(by=['ratio_rome'], ascending=False)
    )
    df_rs['cumsum'] =  100 - df_rs['ratio_rome'].cumsum()
    df_rs = df_rs.head(10)
     
    df_nf.loc[df_nf['naf'].isin(df_rs['naf']), 'score'] += 1
    df_nf = df_nf.loc[df_nf['score'].ge(1)]

    
    return (
        df_nf.sort_values(by=['score'], ascending=False)
             .head(output_size)
    )[['rome', 'naf', 'score']]

# %%
# Rome=>Naf in function form
# Latest
def rome2nafz_v2(rome, df_in, output_size=15):
    """
    Generate naf list using input rome code and specific dataframe:
    ['rome', 'naf', 'embauches', 'embauches_total_n', 'embauches_total_r', 'ratio_naf', 'ratio_rome']
    
    - First a table is generated listing the naf codes who employ the highest percentage
    (from their total recruitments) of the specified rome code, a score is specified with
    a binning technique
    - Then the NAF codes who also appear in the list of where the specified rome code tends
    to work at are boosted
    - Finaly the result is filtered keeping only those with a score of 1 or higher, and from those
    only the first 15 are kept (can be changed by parameter)
    """
    df_nf = (
    df_in.loc[df_in.rome == rome]
         .sort_values(by=['ratio_naf'], ascending=False)
    )
    df_nf['cumsum'] =  100 - df_nf['ratio_rome'].cumsum()
    #df_nf = df_nf.loc[df_nf['cumsum'] > 25]
    df_nf['score_naf'] = pd.to_numeric(pd.cut(
        df_nf['ratio_naf'],
        bins=[0, 2, 5, 10, 50, 100],
        labels=[0, 1, 2, 3, 4]
    ))
    df_nf['score_rome'] = pd.to_numeric(pd.cut(
        df_nf['ratio_rome'],
        bins=[0, 2, 5, 10, 50, 100],
        labels=[0, 1, 2, 3, 4]
    ))
    
    df_nf = df_nf.loc[df_nf['score_naf'].ge(1) | df_nf['score_rome'].ge(1)]
    df_nf['score'] = df_nf['score_naf'] * 4 + df_nf['score_rome']
    df_nf['score'] = pd.cut(
        df_nf['score_naf'] * 3 + df_nf['score_rome'],
        bins=5,
        labels=[1,2,3,4,5]
    )
    
    return (
        df_nf.sort_values(by=['score'], ascending=False)
             .head(output_size)
    )[['rome', 'naf', 'score']]

# %% [markdown]
# ### Vérification de la fonction

# %%
# Function V1
ROME = 'D1101'
print(f"Table ROME=>NAF pour \"{rome_labels.loc[(rome_labels['rome'] == ROME, 'label')].iloc[0]}\"")
df  = rome2nafz_v1(ROME, naf_i)
df.merge(naf_labels, on='naf')[['naf', 'label','score']]
assert(len(df) == 15)
df.head(5)
# Out:
# Table ROME=>NAF pour "Boucherie"
#         rome    naf  score
# 12720  D1101  4722Z    4.0
# 12883  D1101  1013B    3.0
# 12562  D1101  1011Z    3.0
# 12696  D1101  4632A    3.0
# 12716  D1101  4711D    2.0

# %%
# Function Test
df  = rome2nafz_v2(ROME, naf_i)
df.merge(naf_labels, on='naf')[['naf', 'label','score']]
assert(len(df) == 15)
df.head(5)
# Out:
#         rome    naf score
# 12720  D1101  4722Z     5
# 12562  D1101  1011Z     4
# 12696  D1101  4632A     4
# 12883  D1101  1013B     3
# 12716  D1101  4711D     3

# %% [markdown]
# ### Calcul de pour l'ensemble des codes ROME

# %%
result_table = {}
for index, row in rome_labels.iterrows():
    result_table[row.rome] = rome2nafz_v2(str(row.rome), naf_i).to_dict('r')
    print(f"row {index} : {len(result_table[row.rome])} Naf codes for Rome {row.rome} \"{rome_labels.loc[(rome_labels['rome'] == row.rome, 'label')].iloc[0]}\" ")
# Out:
# row 0 : 15 Naf codes for Rome A1101 "Conduite d'engins agricoles et forestiers"
# row 1 : 11 Naf codes for Rome A1201 "Bûcheronnage et élagage"
# row 2 : 7 Naf codes for Rome A1202 "Entretien des espaces naturels"
# row 3 : 15 Naf codes for Rome A1203 "Entretien des espaces verts"
# row 4 : 8 Naf codes for Rome A1204 "Protection du patrimoine naturel"
# row 5 : 8 Naf codes for Rome A1205 "Sylviculture"
# row 6 : 13 Naf codes for Rome A1301 "Conseil et assistance technique en agriculture"
# row 7 : 9 Naf codes for Rome A1302 "Contrôle et diagnostic technique en agriculture"
# row 8 : 15 Naf codes for Rome A1303 "Ingénierie en agriculture et environnement naturel"
# row 9 : 15 Naf codes for Rome A1401 "Aide agricole de production fruitière ou viticole"
# row 10 : 15 Naf codes for Rome A1402 "Aide agricole de production légumière ou végétale"
# row 11 : 15 Naf codes for Rome A1403 "Aide d'élevage agricole et aquacole"
# row 12 : 11 Naf codes for Rome A1404 "Aquaculture"
# row 13 : 13 Naf codes for Rome A1405 "Arboriculture et viticulture"
# row 14 : 15 Naf codes for Rome A1406 "Encadrement équipage de la pêche"
# row 15 : 15 Naf codes for Rome A1407 "Élevage bovin ou équin"
# row 16 : 15 Naf codes for Rome A1408 "Élevage d'animaux sauvages ou de compagnie"
# row 17 : 6 Naf codes for Rome A1409 "Élevage de lapins et volailles"
# row 18 : 10 Naf codes for Rome A1410 "Élevage ovin ou caprin"
# row 19 : 7 Naf codes for Rome A1411 "Élevage porcin"
# row 20 : 7 Naf codes for Rome A1412 "Fabrication et affinage de fromages"
# row 21 : 11 Naf codes for Rome A1413 "Fermentation de boissons alcoolisées"
# row 22 : 15 Naf codes for Rome A1414 "Horticulture et maraîchage"
# row 23 : 10 Naf codes for Rome A1415 "Equipage de la pêche"
# row 24 : 15 Naf codes for Rome A1416 "Polyculture, élevage"
# row 25 : 15 Naf codes for Rome A1417 "Saliculture"
# row 26 : 10 Naf codes for Rome A1501 "Aide aux soins animaux"
# row 27 : 4 Naf codes for Rome A1502 "Podologie animale"
# row 28 : 11 Naf codes for Rome A1503 "Toilettage des animaux"
# row 29 : 2 Naf codes for Rome A1504 "Santé animale"
# row 30 : 8 Naf codes for Rome B1101 "Création en arts plastiques"
# row 31 : 9 Naf codes for Rome B1201 "Réalisation d'objets décoratifs et utilitaires en céramique et matériaux de synthèse"
# row 32 : 7 Naf codes for Rome B1301 "Décoration d'espaces de vente et d'exposition"
# row 33 : 7 Naf codes for Rome B1302 "Décoration d'objets d'art et artisanaux"
# row 34 : 12 Naf codes for Rome B1303 "Gravure - ciselure"
# row 35 : 15 Naf codes for Rome B1401 "Réalisation d'objets en lianes, fibres et brins végétaux"
# row 36 : 11 Naf codes for Rome B1402 "Reliure et restauration de livres et archives"
# row 37 : 13 Naf codes for Rome B1501 "Fabrication et réparation d'instruments de musique"
# row 38 : 6 Naf codes for Rome B1601 "Métallerie d'art"
# row 39 : 8 Naf codes for Rome B1602 "Réalisation d'objets artistiques et fonctionnels en verre"
# row 40 : 8 Naf codes for Rome B1603 "Réalisation d'ouvrages en bijouterie, joaillerie et orfèvrerie"
# row 41 : 11 Naf codes for Rome B1604 "Réparation - montage en systèmes horlogers"
# row 42 : 6 Naf codes for Rome B1701 "Conservation et reconstitution d'espèces animales"
# row 43 : 15 Naf codes for Rome B1801 "Réalisation d'articles de chapellerie"
# row 44 : 6 Naf codes for Rome B1802 "Réalisation d'articles en cuir et matériaux souples (hors vêtement)"
# row 45 : 15 Naf codes for Rome B1803 "Réalisation de vêtements sur mesure ou en petite série"
# row 46 : 14 Naf codes for Rome B1804 "Réalisation d'ouvrages d'art en fils"
# row 47 : 14 Naf codes for Rome B1805 "Stylisme"
# row 48 : 11 Naf codes for Rome B1806 "Tapisserie - décoration en ameublement"
# row 49 : 10 Naf codes for Rome C1101 "Conception - développement produits d'assurances"
# row 50 : 12 Naf codes for Rome C1102 "Conseil clientèle en assurances"
# row 51 : 7 Naf codes for Rome C1103 "Courtage en assurances"
# row 52 : 5 Naf codes for Rome C1104 "Direction d'exploitation en assurances"
# row 53 : 8 Naf codes for Rome C1105 "Études actuarielles en assurances"
# row 54 : 9 Naf codes for Rome C1106 "Expertise risques en assurances"
# row 55 : 6 Naf codes for Rome C1107 "Indemnisations en assurances"
# row 56 : 7 Naf codes for Rome C1108 "Management de groupe et de service en assurances"
# row 57 : 13 Naf codes for Rome C1109 "Rédaction et gestion en assurances"
# row 58 : 3 Naf codes for Rome C1110 "Souscription d'assurances"
# row 59 : 9 Naf codes for Rome C1201 "Accueil et services bancaires"
# row 60 : 10 Naf codes for Rome C1202 "Analyse de crédits et risques bancaires"
# row 61 : 6 Naf codes for Rome C1203 "Relation clients banque/finance"
# row 62 : 9 Naf codes for Rome C1204 "Conception et expertise produits bancaires et financiers"
# row 459 : 10 Naf codes for Rome M1301 "Direction de grande entreprise ou d'établissement public"
# row 460 : 6 Naf codes for Rome M1302 "Direction de petite ou moyenne entreprise"
# row 461 : 3 Naf codes for Rome M1401 "Conduite d'enquêtes"
# row 462 : 15 Naf codes for Rome M1402 "Conseil en organisation et management d'entreprise"
# row 463 : 10 Naf codes for Rome M1403 "Études et prospectives socio-économiques"
# row 464 : 4 Naf codes for Rome M1404 "Management et gestion d'enquêtes"
# row 465 : 15 Naf codes for Rome M1501 "Assistanat en ressources humaines"
# row 466 : 15 Naf codes for Rome M1502 "Développement des ressources humaines"
# row 467 : 13 Naf codes for Rome M1503 "Management des ressources humaines"
# row 468 : 15 Naf codes for Rome M1601 "Accueil et renseignements"
# row 469 : 15 Naf codes for Rome M1602 "Opérations administratives"
# row 470 : 6 Naf codes for Rome M1603 "Distribution de documents"
# row 471 : 15 Naf codes for Rome M1604 "Assistanat de direction"
# row 472 : 15 Naf codes for Rome M1605 "Assistanat technique et administratif"
# row 473 : 6 Naf codes for Rome M1606 "Saisie de données"
# row 474 : 15 Naf codes for Rome M1607 "Secrétariat"
# row 475 : 7 Naf codes for Rome M1608 "Secrétariat comptable"
# row 476 : 15 Naf codes for Rome M1609 "Secrétariat et assistanat médical ou médico-social"
# row 477 : 6 Naf codes for Rome M1701 "Administration des ventes"
# row 478 : 10 Naf codes for Rome M1702 "Analyse de tendance"
# row 479 : 14 Naf codes for Rome M1703 "Management et gestion de produit"
# row 480 : 6 Naf codes for Rome M1704 "Management relation clientèle"
# row 481 : 15 Naf codes for Rome M1705 "Marketing"
# row 482 : 5 Naf codes for Rome M1706 "Promotion des ventes"
# row 483 : 15 Naf codes for Rome M1707 "Stratégie commerciale"
# row 484 : 15 Naf codes for Rome M1801 "Administration de systèmes d'information"
# row 485 : 6 Naf codes for Rome M1802 "Expertise et support en systèmes d'information"
# row 486 : 15 Naf codes for Rome M1803 "Direction des systèmes d'information"
# row 487 : 10 Naf codes for Rome M1804 "Études et développement de réseaux de télécoms"
# row 488 : 15 Naf codes for Rome M1805 "Études et développement informatique"
# row 489 : 7 Naf codes for Rome M1806 "Conseil et maîtrise d'ouvrage en systèmes d'information"
# row 490 : 14 Naf codes for Rome M1807 "Exploitation de systèmes de communication et de commandement"
# row 491 : 10 Naf codes for Rome M1808 "Information géographique"
# row 492 : 12 Naf codes for Rome M1809 "Information météorologique"
# row 493 : 9 Naf codes for Rome M1810 "Production et exploitation de systèmes d'information"
# row 494 : 15 Naf codes for Rome N1101 "Conduite d'engins de déplacement des charges"
# row 495 : 4 Naf codes for Rome N1102 "Déménagement"
# row 496 : 15 Naf codes for Rome N1103 "Magasinage et préparation de commandes"
# row 497 : 9 Naf codes for Rome N1104 "Manoeuvre et conduite d'engins lourds de manutention"
# row 498 : 15 Naf codes for Rome N1105 "Manutention manuelle de charges"
# row 499 : 6 Naf codes for Rome N1201 "Affrètement transport"
# row 500 : 6 Naf codes for Rome N1202 "Gestion des opérations de circulation internationale des marchandises"
# row 501 : 10 Naf codes for Rome N1301 "Conception et organisation de la chaîne logistique"
# row 502 : 4 Naf codes for Rome N1302 "Direction de site logistique"
# row 503 : 15 Naf codes for Rome N1303 "Intervention technique d'exploitation logistique"
# row 504 : 10 Naf codes for Rome N2101 "Navigation commerciale aérienne"
# row 505 : 7 Naf codes for Rome N2102 "Pilotage et navigation technique aérienne"
# row 506 : 10 Naf codes for Rome N2201 "Personnel d'escale aéroportuaire"
# row 507 : 15 Naf codes for Rome N2202 "Contrôle de la navigation aérienne"
# row 508 : 8 Naf codes for Rome N2203 "Exploitation des pistes aéroportuaires"
# row 509 : 6 Naf codes for Rome N2204 "Préparation des vols"
# row 510 : 14 Naf codes for Rome N2205 "Direction d'escale et exploitation aéroportuaire"
# row 511 : 12 Naf codes for Rome N3101 "Encadrement de la navigation maritime"
# row 512 : 10 Naf codes for Rome N3102 "Equipage de la navigation maritime"
# row 513 : 10 Naf codes for Rome N3103 "Navigation fluviale"
# row 514 : 9 Naf codes for Rome N3201 "Exploitation des opérations portuaires et du transport maritime"
# row 515 : 14 Naf codes for Rome N3202 "Exploitation du transport fluvial"
# row 516 : 3 Naf codes for Rome N3203 "Manutention portuaire"
# row 517 : 15 Naf codes for Rome N4101 "Conduite de transport de marchandises sur longue distance"
# row 518 : 12 Naf codes for Rome N4102 "Conduite de transport de particuliers"
# row 519 : 7 Naf codes for Rome N4103 "Conduite de transport en commun sur route"
# row 520 : 10 Naf codes for Rome N4104 "Courses et livraisons express"
# row 521 : 15 Naf codes for Rome N4105 "Conduite et livraison par tournées sur courte distance"
# row 522 : 5 Naf codes for Rome N4201 "Direction d'exploitation des transports routiers de marchandises"
# row 523 : 9 Naf codes for Rome N4202 "Direction d'exploitation des transports routiers de personnes"
# row 524 : 6 Naf codes for Rome N4203 "Intervention technique d'exploitation des transports routiers de marchandises"
# row 525 : 8 Naf codes for Rome N4204 "Intervention technique d'exploitation des transports routiers de personnes"
# row 526 : 10 Naf codes for Rome N4301 "Conduite sur rails"
# row 527 : 7 Naf codes for Rome N4302 "Contrôle des transports en commun"
# row 528 : 9 Naf codes for Rome N4401 "Circulation du réseau ferré"
# row 529 : 3 Naf codes for Rome N4402 "Exploitation et manoeuvre des remontées mécaniques"
# row 530 : 11 Naf codes for Rome N4403 "Manoeuvre du réseau ferré"

# %% [markdown]
# ### Écriture du fichier CSV et fin du traitement

# %%
# Write CSV File
import csv
import time
output = f"/outputs/andi_rome2naf_{time.strftime('%Y%m%d')}.csv"
i = 0
with open(output, 'w') as file:
    writer = csv.DictWriter(
        file,
        delimiter=',',
        quotechar='"',
        quoting=csv.QUOTE_MINIMAL,
        fieldnames=['rome', 'rome_label', 'naf', 'naf_label', 'score']
    )
    writer.writeheader()
    for rome, naflist in result_table.items():
        for data in naflist:
            data['rome_label'] = rome_labels.loc[(rome_labels['rome'] == rome, 'label')].iloc[0]
            data['naf_label'] = naf_labels.loc[(naf_labels['naf'] == data['naf'], 'label')].iloc[0]
            writer.writerow(data)
            i += 1
print(f'Wrote {i} rows to {output}')

# Crash to end automatic cell execution
raise SystemExit("Fin traitement automatique")
# Out:
# Wrote 5342 rows to /outputs/andi_rome2naf_20200130.csv
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: Fin traitement automatique

# %% [markdown]
# ### Code historique - documentation

# %%
# Legacy Code

# df_ok['score'] = 0
# df_ok.loc[df_cumsum < 15, 'score'] = 5
# df_ok['score'] = pd.cut(
 #   df_ok['cumsum'],
 #   bins=[0, 15, 30, 45, 60, 100],
 #   labels=[5, 4, 3, 2, 1]
#)
#df_ok

#df_base['score'] = 0
#df_base.loc[df_base['cumsum'].ge(0), 'score'] = 0
#df_base.loc[df_base['cumsum'].ge(15).lt(30), 'score'] = 1
#df_base.loc[df_base['cumsum'].ge(30).lt(45), 'score'] = 2
#df_base.loc[df_base['cumsum'].ge(45).lt(60), 'score'] = 3
#df_base.loc[df_base['cumsum'].ge(60), 'score'] = 4
#df_base

# %%
def display_result(rome, table, naf_labels):
    print(f"Résultat(s) pour {rome} - \"{rome_labels.loc[(rome_labels['rome'] == rome, 'label')].iloc[0]}\"")
    df = pd.DataFrame(table[rome])
    df = df.merge(naf_labels, on='naf')[['naf', 'label','score']]
    display(HTML(df.head(15).to_html()))


# display_result('A1303', result_table, naf_labels)
display_result('N4104', result_table, naf_labels)
# rome2nafz(t1, naf_i)
# Out:
# Résultat(s) pour N4104 - "Courses et livraisons express"
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-56-ef46725672af> in <module>
#       7
#       8 # display_result('A1303', result_table, naf_labels)
# ----> 9 display_result('N4104', result_table, naf_labels)
#      10 # rome2nafz(t1, naf_i)
#
# <ipython-input-56-ef46725672af> in display_result(rome, table, naf_labels)
#       2     print(f"Résultat(s) pour {rome} - \"{rome_labels.loc[(rome_labels['rome'] == rome, 'label')].iloc[0]}\"")
#       3     df = pd.DataFrame(table[rome])
# ----> 4     df = df.merge(naf_labels, on='naf')[['naf', 'label','score']]
#       5     display(HTML(df.head(15).to_html()))
#       6
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    7347             copy=copy,
#    7348             indicator=indicator,
# -> 7349             validate=validate,
#    7350         )
#    7351
#
# /usr/local/lib/python3.7/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      79         copy=copy,
#      80         indicator=indicator,
# ---> 81         validate=validate,
#      82     )
#      83     return op.get_result()
#
# /usr/local/lib/python3.7/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     624             self.right_join_keys,
#     625             self.join_names,
# --> 626         ) = self._get_merge_keys()
#     627
#     628         # validate the merge keys dtypes. We may need to coerce
#
# /usr/local/lib/python3.7/site-packages/pandas/core/reshape/merge.py in _get_merge_keys(self)
#     986                         right_keys.append(rk)
#     987                     if lk is not None:
# --> 988                         left_keys.append(left._get_label_or_level_values(lk))
#     989                         join_names.append(lk)
#     990                     else:
#
# /usr/local/lib/python3.7/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1772             values = self.axes[axis].get_level_values(key)._values
#    1773         else:
# -> 1774             raise KeyError(key)
#    1775
#    1776         # Check for duplicates
#
# KeyError: 'naf'

# %%
## Vérification de la couverture des rome: génère une liste de rome sans corresponces naf,
## avec un résumé des données brutes
romes = []
labels = []
embauches = []
naf_total = []
naf_liste = []

data = []

emploi_rome_naf['naf2'] = emploi_rome_naf['naf']
ren = emploi_rome_naf.groupby('rome').agg(
    embauches_total_r=pd.NamedAgg(column='embauches', aggfunc=sum),
    naf_list=pd.NamedAgg(column='naf', aggfunc=lambda x: ' '.join(x)),
    naf_count = pd.NamedAgg(column='naf2', aggfunc=lambda x: len(x))
)

for index, row in rome_labels.iterrows():
    test_rome = row['rome']
    df = pd.DataFrame(result_table[test_rome])
    if len(df) == 0:
        data.append([
            test_rome,
            row['label'],
            ren.loc[(ren.index == test_rome, 'embauches_total_r')].iloc[0],
            ren.loc[(ren.index == test_rome, 'naf_count')].iloc[0],
            ren.loc[(ren.index == test_rome, 'naf_list')].iloc[0],
        ])

bilan = pd.DataFrame(
    data,
    columns=['romes','labels','embauches','naf_total','naf_list']
)
pd.set_option('display.max_rows', None)
bilan.head(100)
# Out:
# Empty DataFrame
# Columns: [romes, labels, embauches, naf_total, naf_list]
# Index: []

# %%
emploi_rome_naf['naf2'] = emploi_rome_naf['naf']
rome_embauches_naf = emploi_rome_naf.groupby('rome').agg(
    embauches_total_r=pd.NamedAgg(column='embauches', aggfunc=sum),
    naf=pd.NamedAgg(column='naf', aggfunc=lambda x: ' '.join(x)),
    naf_count = pd.NamedAgg(column='naf2', aggfunc=lambda x: len(x))
)

rome_embauches_naf.loc[rome_embauches_naf.index == 'A1101']
# Out:
#        embauches_total_r                                                naf  \
# rome
# A1101               4653  0111Z 0113Z 0114Z 0119Z 0121Z 0122Z 0123Z 0124...
#
#        naf_count
# rome
# A1101        365

# %%
## Andi Matching API Naf criteria build testing
import os

def get_andidata_naflist(romes, include=None, exclude=None):
    # current_dir = os.path.dirname(os.path.abspath(__file__))
    # filename = f"{current_dir}/data_files/{ANDIDATA_FILE}.csv"
    filename="/outputs/andi_rome2naf_20200130.csv"
    
    include_list = []
    exclude_list = []
    with open(filename) as csvfile:
        rdr = csv.DictReader(
            csvfile,
            delimiter=',',
            quotechar='"',
            quoting=csv.QUOTE_MINIMAL,
        )
        for row in rdr:
            if row['rome'] in romes:
                include_list.append(row)
            if include and row['rome'] in include:
                include_list.append(row)
            if exclude and row['rome'] in exclude:
                exclude_list.append(row['naf'])

    include_list[:] = [el for el in include_list if el['naf'] not in exclude_list]
    out_list = {x['naf']: x['score'] for x in include_list}

    return [out_list, {}]

def get_naf_sql(rules):
    '''
    Get sql rules to select naf code
    '''
    codes, domains = rules
    sql = []
    for naf, value in codes.items():
        sql.append(f'WHEN \'{naf}\' THEN {value}')

    if domains:
        sql.append('ELSE CASE substring(e.naf, 0, 3)')
        for naf, value in domains.items():
            value -= 1
            sql.append(f'WHEN \'{naf}\' THEN {value}')

    sql.append('ELSE 1')

    if domains:
        sql.append('END')

    return "\n".join(sql)

rules = get_andidata_naflist('K1707')
print(rules)
print(get_naf_sql(rules))
# Out:
# [{}, {}]
# ELSE 1

# %%
# Compute best nafs for rome
pd.set_option('display.max_rows', 20)
def display_df(df):
    display(HTML(df.to_html()))
    
ROME = 'K1707' # Policier
ROME = 'M1809' # Information météorologique
ROME = 'D1101' # Boucher
ROME = 'J1202'

print(f"Table ROME=>NAF pour \"{rome_labels.loc[(rome_labels['rome'] == ROME, 'label')].iloc[0]}\"")

# Basic order based on employment percentage
# Use rome recruitment % by naf ratio, stop @ 75% of total rome pool
df_base = (
naf_i.loc[naf_i.rome == ROME]
    .sort_values(by=['ratio_naf'], ascending=False)
)
print('Step 1')
display_df(df_base[df_base.rome == ROME].head(20))

df_base['cumsum'] =  100 - df_base['ratio_rome'].cumsum()

print('Step 1bis: cumsum')
display_df(df_base[df_base.rome == ROME].head(20))

#df_base = df_base.loc[df_base['cumsum'] > 15]
df_base['score_naf'] = pd.to_numeric(pd.cut(
    df_base['ratio_naf'],
    bins=[0, 2, 5, 10, 50, 100],
    labels=[1, 2, 3, 4, 5]
))
df_base['score_rome'] = pd.to_numeric(pd.cut(
    df_base['ratio_rome'],
    bins=[0, 2, 5, 10, 50, 100],
    labels=[1, 2, 3, 4, 5]
))


print('Step 2: prior to boost')
display_df(df_base[df_base.rome == ROME].head(20))

# Boosting scores with rome orientations
# If naf is in top 10 of rome destinations, increment score
#df_rs = (
#naf_i.loc[naf_i.rome == ROME ]
#    .sort_values(by=['ratio_rome'], ascending=False)
#)
#df_rs['cumsum'] =  100 - df_rs['ratio_rome'].cumsum()
#df_rs = df_rs.head(10)
#df_base.loc[df_base['naf'].isin(df_rs['naf']), 'score'] += 1

print('Step 3')
display_df(df_base[df_base.rome == ROME].head(20))

df_base = df_base.loc[df_base['score_naf'].ge(1) | df_base['score_rome'].ge(1)]
df_base['score'] = pd.cut(
    df_base['score_naf'] * 3 + df_base['score_rome'],
    bins=5,
    labels=[1,2,3,4,5]
)
# Display
(
df_base
    .merge(naf_labels, on='naf')
    .sort_values(by=['score'], ascending=False)
    [['rome', 'naf', 'label','score', 'score_naf', 'score_rome']]
).head(15)
# Out:
# Table ROME=>NAF pour "Pharmacie"
# Step 1
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>rome</th>
#       <th>naf</th>
#       <th>embauches</th>
#       <th>embauches_total_n</th>
#       <th>embauches_total_r</th>
#       <th>ratio_naf</th>
#       <th>ratio_rome</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>166157</th>
#       <td>J1202</td>
#       <td>4773Z</td>
#       <td>6066</td>
#       <td>18976</td>
#       <td>7410</td>
#       <td>31.966695</td>
#       <td>81.862348</td>
#     </tr>
#     <tr>
#       <th>166174</th>
#       <td>J1202</td>
#       <td>9492Z</td>
#       <td>3</td>
#       <td>155</td>
#       <td>7410</td>
#       <td>1.935484</td>
#       <td>0.040486</td>
#     </tr>
#     <tr>
#       <th>166132</th>
#       <td>J1202</td>
#       <td>4774Z</td>
#       <td>34</td>
#       <td>3894</td>
#       <td>7410</td>
#       <td>0.873138</td>
#       <td>0.458839</td>
#     </tr>
#     <tr>
#       <th>166043</th>
#       <td>J1202</td>
#       <td>4646Z</td>
#       <td>65</td>
#       <td>8524</td>
#       <td>7410</td>
#       <td>0.762553</td>
#       <td>0.877193</td>
#     </tr>
#     <tr>
#       <th>166080</th>
#       <td>J1202</td>
